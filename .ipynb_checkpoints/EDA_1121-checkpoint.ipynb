# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances

# %% [markdown]
# # Import Dataframe

# %% [markdown]
# The first two dataframes were scraped from basket-ballreference.com from the 2018-2019 season

# %%
poss = pd.read_csv('season1819.csv')
ad_1819 = pd.read_csv('ad_1819.csv')

# %%
#dropping the duplicates of each dataframe
poss = poss.drop_duplicates(subset = 'Player', keep = 'first')
ad_1819 = ad_1819.drop_duplicates(subset = 'Player', keep = 'first')

# %%
poss = poss.drop(['Unnamed: 0', 'Unnamed: 29', 'url_list', 'GS'], axis = 1)
ad_1819 = ad_1819.drop(['Unnamed: 0', 'Pos', 'Age', 'Tm', 'G',
                       'MP'], axis = 1)

# %%
season = pd.merge(poss, ad_1819, on = 'Player')
season = season.fillna(0)
season = season[season['G'] > 30]

# %%
season.shape
# Out:
# (384, 51)

# %%
season.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB',
#        'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'ORtg', 'DRtg', 'PER',
#        'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%',
#        'TOV%', 'USG%', ' ', 'OWS', 'DWS', 'WS', 'WS/48', ' .1', 'OBPM', 'DBPM',
#        'BPM', 'VORP'],
#       dtype='object')

# %% [markdown]
# # Rec system

# %%
df= season.drop(columns = ['Pos', 'Age', 'Tm', 'G', 'MP'],
               axis = 1)

# %%
df.head()
# Out:
#               Player    FG   FGA    FG%   3P   3PA    3P%    2P   2PA    2P%  \
# 0       Álex Abrines   4.4  12.5  0.357  3.3  10.1  0.323   1.2   2.4  0.500
# 2       Jaylen Adams   4.1  11.9  0.345  2.7   8.0  0.338   1.4   3.9  0.361
# 3       Steven Adams   8.4  14.1  0.595  0.0   0.0  0.000   8.4  14.1  0.596
# 4        Bam Adebayo   7.2  12.4  0.576  0.1   0.4  0.200   7.1  12.0  0.588
# 7  LaMarcus Aldridge  12.4  24.0  0.519  0.2   0.8  0.238  12.3  23.2  0.528
#
#    ...       OWS  DWS   WS  WS/48   .1  OBPM  DBPM  BPM  VORP
# 0  ...  0.0  0.1  0.6  0.6  0.053  0.0  -2.4  -0.9 -3.4  -0.2
# 2  ...  0.0 -0.1  0.2  0.1  0.011  0.0  -3.1  -1.3 -4.4  -0.3
# 3  ...  0.0  5.1  4.0  9.1  0.163  0.0   0.6   2.1  2.7   3.2
# 4  ...  0.0  3.4  3.4  6.8  0.171  0.0  -0.6   3.6  3.0   2.4
# 7  ...  0.0  6.4  2.9  9.3  0.167  0.0   1.2   0.5  1.6   2.5
#
# [5 rows x 46 columns]

# %%
pivot = pd.pivot_table(df, index = 'Player')
pivot.head()
# Out:
#                   2P    2P%   2PA   3P    3P%  3PA   3PAr  AST  AST%  BLK  \
# Player
# Aaron Gordon     6.5  0.499  13.0  2.2  0.349  6.4  0.332  5.4  16.6  1.0
# Aaron Holiday    4.7  0.459  10.2  3.3  0.339  9.6  0.485  6.6  19.3  1.0
# Abdel Nader      4.0  0.513   7.7  2.2  0.320  6.7  0.465  1.3   3.8  0.8
# Al Horford       7.7  0.604  12.7  1.8  0.360  5.0  0.281  6.9  21.2  2.1
# Al-Farouq Aminu  3.4  0.514   6.6  2.0  0.343  5.9  0.472  2.2   6.0  0.7
#
#                  ...  TOV%   TRB  TRB%    TS%  USG%  VORP   WS  WS/48       \
# Player           ...
# Aaron Gordon     ...  12.3  10.7  11.7  0.538  21.8   2.0  5.1  0.093  0.0
# Aaron Holiday    ...  12.3   5.1   5.8  0.518  21.9  -0.1  0.9  0.065  0.0
# Abdel Nader      ...  10.1   7.8   8.6  0.522  15.1  -0.5  0.9  0.062  0.0
# Al Horford       ...  11.8  11.2  12.4  0.605  18.9   3.4  7.5  0.181  0.0
# Al-Farouq Aminu  ...   9.7  12.9  14.2  0.568  13.7   1.7  5.8  0.121  0.0
#
#                   .1
# Player
# Aaron Gordon     0.0
# Aaron Holiday    0.0
# Abdel Nader      0.0
# Al Horford       0.0
# Al-Farouq Aminu  0.0
#
# [5 rows x 45 columns]

# %%
#create a sparse matrix
sparse_pivot = sparse.csr_matrix(pivot.fillna(0))

# %%
#calculating cosine similarity
recommender = pairwise_distances(sparse_pivot, metric = 'cosine')

# %%
#creating recommender dataframe
rec_df = pd.DataFrame(recommender, columns = pivot.index, index = pivot.index)
rec_df.head()
# Out:
# Player           Aaron Gordon  Aaron Holiday  Abdel Nader  Al Horford  \
# Player
# Aaron Gordon         0.000000       0.005069     0.009363    0.004501
# Aaron Holiday        0.005069       0.000000     0.009764    0.012154
# Abdel Nader          0.009363       0.009764     0.000000    0.017568
# Al Horford           0.004501       0.012154     0.017568    0.000000
# Al-Farouq Aminu      0.009193       0.018283     0.006740    0.009383
#
# Player           Al-Farouq Aminu  Alec Burks  Alex Len  Alfonzo McKinnie  \
# Player
# Aaron Gordon            0.009193    0.002712  0.002958          0.010256
# Aaron Holiday           0.018283    0.003524  0.009880          0.015584
# Abdel Nader             0.006740    0.003440  0.008053          0.003619
# Al Horford              0.009383    0.009946  0.007917          0.012708
# Al-Farouq Aminu         0.000000    0.008194  0.007877          0.002439
#
# Player           Allen Crabbe  Allonzo Trier  ...  Wesley Matthews  \
# Player                                        ...
# Aaron Gordon         0.010953       0.005497  ...         0.008987
# Aaron Holiday        0.007667       0.003310  ...         0.003975
# Abdel Nader          0.002034       0.006039  ...         0.005081
# Al Horford           0.020902       0.015533  ...         0.015366
# Al-Farouq Aminu      0.011331       0.015507  ...         0.013110
#
# Player           Will Barton  Willie Cauley-Stein  Willy Hernangómez  \
# Player
# Aaron Gordon        0.002586             0.005394           0.007730
# Aaron Holiday       0.002108             0.017615           0.021383
# Abdel Nader         0.004529             0.013166           0.017882
# Al Horford          0.010756             0.004293           0.010045
# Al-Farouq Aminu     0.011037             0.005051           0.010515
#
# Player           Wilson Chandler  Yogi Ferrell  Zach Collins  Zach LaVine  \
# Player
# Aaron Gordon            0.011189      0.007577      0.005133     0.007497
# Aaron Holiday           0.011858      0.003849      0.011147     0.006383
# Abdel Nader             0.003144      0.006435      0.004508     0.023334
# Al Horford              0.015664      0.010392      0.008188     0.016014
# Al-Farouq Aminu         0.005925      0.011239      0.003473     0.030543
#
# Player           Zaza Pachulia  Álex Abrines
# Player
# Aaron Gordon          0.009524      0.019430
# Aaron Holiday         0.019035      0.013473
# Abdel Nader           0.013500      0.004558
# Al Horford            0.009897      0.026728
# Al-Farouq Aminu       0.006971      0.014193
#
# [5 rows x 384 columns]

# %%
#evaluating matrix
rec_df['LeBron James'].sort_values()[1:11]
# Out:
# Player
# Luka Dončić          0.003295
# Kyrie Irving         0.003422
# Blake Griffin        0.003675
# Nikola Jokić         0.005122
# Russell Westbrook    0.005202
# Kevin Durant         0.005343
# D'Angelo Russell     0.006240
# Victor Oladipo       0.006512
# Kemba Walker         0.006701
# Damian Lillard       0.006719
# Name: LeBron James, dtype: float64

# %%
season.loc[season['Player'].str.contains('James'), 'Player']
# Out:
# 156      James Ennis
# 206     James Harden
# 258     LeBron James
# 265    James Johnson
# Name: Player, dtype: object

# %% [markdown]
# ## Attempting to combine both dataframes

# %%
scrape538 = pd.read_csv('data/scrape538.csv', index_col = False)
scrape538 = scrape538.drop(columns = 'Unnamed: 0')

# %%
scrape538.columns
# Out:
# Index(['Player', 'Team', 'Position(s)', 'Minutes', 'BSR Off.', 'BSR Def.',
#        'BSR Total', 'OOR Off.', 'OOR Def.', 'OOR Total', 'OVR Off.',
#        'OVR Def.', 'OVR total', 'WAR'],
#       dtype='object')

# %%
print(len(scrape538))
print(len(season))
# Out:
# 447
# 384

# %% [markdown]
# # EDA

# %%
sns.catplot(x = 'WS', y ='VORP', hue = 'Pos', data=season, alpha = 0.5,
           height = 7)

plt.xlabel("Win Shares", fontsize = 15)
plt.ylabel("Value over Replacement ", fontsize = 15)
plt.title('Wins Sared + VORP score from sports-reference', fontsize = 20)
# Out:
# Text(0.5, 1, 'Wins Sared + VORP score from sports-reference')

# %%
sns.catplot(x = 'ORtg', y ='DRtg', hue = 'Pos', data=season, alpha = 0.5)

plt.xlabel("Points produced/100 possessions", fontsize = 15)
plt.ylabel("Points allowed/100 possessions", fontsize = 15)
plt.title('ORtg + DRtg score from sports-reference', fontsize = 20)
# Out:
# Text(0.5, 1, 'ORtg + DRtg score from sports-reference')

# %%
pct_stats = ['FG%', '3P%', '2P%', 'FT%', 'TS%', 'ORB%',
            'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%',
            'TOV%', 'USG%']

# %%
season[pct_stats]
# Out:
#        FG%    3P%    2P%    FT%    TS%  ORB%  DRB%  TRB%  AST%  STL%  BLK%  \
# 0    0.357  0.323  0.500  0.923  0.507   0.9   7.8   4.2   4.3   1.3   0.9
# 2    0.345  0.338  0.361  0.778  0.474   2.6  12.3   7.4  19.8   1.5   1.0
# 3    0.595  0.000  0.596  0.500  0.591  14.7  14.8  14.7   6.6   2.0   2.4
# 4    0.576  0.200  0.588  0.735  0.623   9.2  24.0  16.6  14.2   1.8   3.0
# 7    0.519  0.238  0.528  0.847  0.576  10.3  19.8  15.1  11.6   0.8   3.4
# ..     ...    ...    ...    ...    ...   ...   ...   ...   ...   ...   ...
# 525  0.527  0.349  0.564  0.644  0.569   8.7  14.4  11.7  12.0   2.4   1.3
# 526  0.418  0.324  0.477  0.829  0.539   2.6  10.2   6.3  40.5   1.3   0.5
# 527  0.551  0.273  0.570  0.787  0.611   9.4  19.7  14.5  12.1   1.5   2.9
# 529  0.553  0.000  0.553  0.705  0.590  10.6  22.8  16.4   7.7   0.6   1.8
# 530  0.559  0.000  0.559  0.802  0.604  11.9  24.2  18.2   9.1   0.6   4.0
#
#      TOV%  USG%
# 0     7.9  12.2
# 2    19.7  13.5
# 3    12.6  16.4
# 4    17.1  15.8
# 7     8.8  26.9
# ..    ...   ...
# 525  12.0  18.0
# 526  17.6  28.4
# 527  13.2  16.3
# 529  13.6  18.2
# 530  13.9  20.3
#
# [384 rows x 13 columns]

# %%
season[pct_stats].plot(kind='hist',rot=0,lw=1,colormap='jet',figsize=(10,10),
             title='Percentage stats', subplots=True, layout=(5,3));

# %%
fig, axes = plt.subplots(round(len(season[pct_stats].columns) / 3), 3, figsize=(12, 30))

for i, ax  in enumerate(fig.axes):
    if i < len(season[pct_stats].columns):
        # https://stackoverflow.com/questions/38809061/remove-some-x-labels-with-seaborn
        ax.xaxis.set_major_formatter(plt.FormatStrFormatter('%d'))
        #x axis label rotation code from Stack overflow
#         ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=45)
        sns.countplot(x=season[pct_stats].columns[i], data=season[pct_stats], ax=ax)
fig.tight_layout()

# %% [markdown]
# # 538 Dataframe

# %% [markdown]
# Last scraped 11/21 - 538 automatically defaults these ratings based on minutes played - As of todya it defaults at 199

# %%
#this is 2019-2020 season rankings form 538
scrape538 = pd.read_csv('data/scrape538.csv') 
scrape538 = scrape538.drop(['Unnamed: 0'], axis = 1)

# %%
scrape538.shape
# Out:
# (447, 14)

# %%
scrape538.head()
# Out:
#                   Player           Team Position(s)  Minutes  BSR Off.  \
# 0           James Harden        Rockets      PG, SG      550      11.1
# 1            Luka Doncic      Mavericks  PG, SG, SF      480      10.8
# 2           LeBron James         Lakers  PG, SF, PF      489       8.0
# 3         Damian Lillard  Trail Blazers          PG      536       8.6
# 4  Giannis Antetokounmpo          Bucks      SF, PF      459       4.4
#
#    BSR Def.  BSR Total  OOR Off.  OOR Def.  OOR Total  OVR Off.  OVR Def.  \
# 0      -0.1       11.0       1.5       9.4       10.9      10.2       1.3
# 1       1.6       12.3       4.9      -5.0       -0.1      10.2       0.7
# 2       0.6        8.6      14.4       1.9       16.3       9.3       0.8
# 3      -2.0        6.6       6.3      -0.3        6.0       8.6      -1.8
# 4       3.3        7.7       3.9       4.7        8.7       4.5       3.6
#
#    OVR total  WAR
# 0       11.5  4.0
# 1       10.9  3.4
# 2       10.1  3.2
# 3        6.8  2.6
# 4        8.1  2.6

# %%
sns.catplot(x = 'OVR total', y ='WAR', hue = 'Team', data=scrape538, alpha = 0.5,
           height= 8)
plt.xlabel("Overall Raptor Score", fontsize = 15)
plt.ylabel("Wins above replacement", fontsize = 15)
plt.title('WAR + OVR total per team', fontsize = 20)
# Out:
# Text(0.5, 1, 'WAR + OVR total per team')
